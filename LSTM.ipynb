# %%
# !python lstm-RNN.py
# Out:
# TensorFlow Version: 1.2.1
# 2017-10-07 20:47:32.317160: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-10-07 20:47:32.317656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: Tesla K80
# major: 3 minor: 7 memoryClockRate (GHz) 0.8235
# pciBusID 0000:00:1e.0
# Total memory: 11.17GiB
# Free memory: 11.11GiB
# 2017-10-07 20:47:32.317686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-10-07 20:47:32.317702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-10-07 20:47:32.317730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0)
# ...

# %%
# !python generate_lstm_sample.py
# Out:
# 2017-10-07 20:50:42.495479: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-10-07 20:50:42.496004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: Tesla K80
# major: 3 minor: 7 memoryClockRate (GHz) 0.8235
# pciBusID 0000:00:1e.0
# Total memory: 11.17GiB
# Free memory: 11.11GiB
# 2017-10-07 20:50:42.496032: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-10-07 20:50:42.496049: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-10-07 20:50:42.496076: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0)
# moe_szyslak: billy_the_kid: you work in!
# ...

# %%
# !python vanilla-RNN.py
# Out:
# TensorFlow Version: 1.2.1
# 2017-10-07 20:51:05.975710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-10-07 20:51:05.976196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: Tesla K80
# major: 3 minor: 7 memoryClockRate (GHz) 0.8235
# pciBusID 0000:00:1e.0
# Total memory: 11.17GiB
# Free memory: 11.11GiB
# 2017-10-07 20:51:05.976220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-10-07 20:51:05.976231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-10-07 20:51:05.976244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0)
# ...

# %%
# !python generate_vanilla_sample.py
# Out:
# 2017-10-07 20:52:14.372873: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-10-07 20:52:14.373363: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: Tesla K80
# major: 3 minor: 7 memoryClockRate (GHz) 0.8235
# pciBusID 0000:00:1e.0
# Total memory: 11.17GiB
# Free memory: 11.11GiB
# 2017-10-07 20:52:14.373388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-10-07 20:52:14.373396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-10-07 20:52:14.373413: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0)
# moe_szyslak: yeah, well, okay... oh my god, i should. it then stabbin' him off the truck.
# ...
